# %%
print ("Hello my name is Wajahat")
# Out:
# Hello my name is Wajahat

# %%
# print in python
print("my name is Wajahat Ali Khan")
print("sap id: 55431")
# ------------------------------------------------------------------------------

# input from user in python
number  = int (input("Enter a number "))
print("The number you entered is: ", number)
#-------------------------------------------------------------------------------

if conditions in python
num = int (input("Enter a number"))
if num % 2 == 0:
  print("The number is even")
else:
  print("The number is odd")
#-------------------------------------------------------------------------------

functions in python
def numberchecker():
  num = int (input("Enter a number "))
  if num % 2 == 0:
    print("The number is even")
  else:
   print("The number is odd")
numberchecker()
numberchecker()
numberchecker()
numberchecker()
numberchecker()
#-------------------------------------------------------------------------------


# for loop in python to print the table of entered number
number = int(input("Enter a number: "))

for i in range(1, 11):
    print(number, "x", i, "=", number * i)
#-------------------------------------------------------------------------------


#to print first 20 prime numbers
def prime_checker():
 count = 20
for i in range(1000):
 if is_prime(i) == 1:
  print("prime numbers")
  count += 1
 elif count == 20:
  break
prime_checker()
#-------------------------------------------------------------------------------


# Lambda function in python to print square of 5
x = 5
square = lambda x: x * x
print("the square of 5 is: ",square(x))
